# %% [markdown]
# # Разбор простого примера с habr.ru

# %% [raw]
# https://habr.com/en/post/349864/

# %%
from yargy import rule, and_, or_, Parser
from yargy.predicates import gte, lte, caseless, normalized, dictionary
from yargy.interpretation import fact
from datetime import date

# %%
DAY = and_(
    gte(1),
    lte(31)
)
MONTH = and_(
    gte(1),
    lte(12)
)
YEAR = and_(
    gte(1),
    lte(2018)
)
DATE = rule(
    YEAR,
    '-',
    MONTH,
    '-',
    DAY
)

parser = Parser(DATE)

text = '''
    2018-02-23,
    2015-12-31;
    8 916 364-12-01
'''

for match in parser.findall(text):
    print(match.span, [x.value for x in match.tokens])
# Out:
# [5, 15) ['2018', '-', '02', '-', '23']
# [21, 31) ['2015', '-', '12', '-', '31']
# [43, 52) ['364', '-', '12', '-', '01']

# %%
MONTHS = {
    'январь',
    'февраль',
    'март',
    'апрель',
    'мая',
    'июнь',
    'июль',
    'август',
    'сентябрь',
    'октябрь',
    'ноябрь',
    'декабрь'
}

MONTH_NAME = dictionary(MONTHS)

YEAR_WORDS = or_(
    rule(caseless('г'), '.'),
    rule(normalized('год'))
)

DATE = or_(
    rule(
        YEAR,
        '-',
        MONTH,
        '-',
        DAY
    ),
    rule(
        DAY,
        MONTH_NAME,
        YEAR,
        YEAR_WORDS.optional()
    )
)

parser = Parser(DATE)

text = '''
    8 января 2014 года, 15 июня 2001 г.,
    31 февраля 2018
'''

for match in parser.findall(text):
    print(match.span, [x.value for x in match.tokens])
# Out:
# [5, 23) ['8', 'января', '2014', 'года']
# [25, 40) ['15', 'июня', '2001', 'г', '.']
# [46, 61) ['31', 'февраля', '2018']

# %%
match = parser.match('05 февраля 2011 года')
match.tree
# match
# Out:
# Tree(Node(BNFRule([Production([AndPredicate([gte(1), lte(2018)]),
#                                eq('-'),
#                                AndPredicate([gte(1), lte(12)]),
#                                eq('-'),
#                                AndPredicate([gte(1), lte(31)])],
#                               0),
#                    Production([AndPredicate([gte(1), lte(31)]),
#                                DictionaryPredicate({'август',
#                                                     'августа',
#                                                     'апрель',
#                                                     'декабрь',
#                                                     'июль',
#                                                     'июнь',
#                                                     'май',
#                                                     'март',
#                                                     'марта',
#                                                     'мая',
#                                                     'ноябрь',
#                                                     'октябрь',
#                                                     'сентябрь',
#                                                     'февраль',
#                                                     'январь'}),
#                                AndPredicate([gte(1), lte(2018)]),
#                                BNFRule([EmptyProduction([], 0),
#                                         Production([BNFRule([Production([caseless('г'),
#                                                                          eq('.')],
#                                                                         0),
#                                                              Production([DictionaryPredicate({'год'})],
#                                                                         0)],
#                                                             'R2',
#                                                             None,
#                                                             None)],
#                                                    0)],
#                                        'R1',
#                                        None,
#                                        None)],
#                               0)],
#                   'R0',
#                   None,
#                   None),
#           Production([AndPredicate([gte(1), lte(31)]),
#                       DictionaryPredicate({'август',
#                                            'августа',
#                                            'апрель',
#                                            'декабрь',
#                                            'июль',
#                                            'июнь',
#                                            'май',
#                                            'март',
#                                            'марта',
#                                            'мая',
#                                            'ноябрь',
#                                            'октябрь',
#                                            'сентябрь',
#                                            'февраль',
#                                            'январь'}),
#                       AndPredicate([gte(1), lte(2018)]),
#                       BNFRule([EmptyProduction([], 0),
#                                Production([BNFRule([Production([caseless('г'),
#                                                                 eq('.')],
#                                                                0),
#                                                     Production([DictionaryPredicate({'год'})],
#                                                                0)],
#                                                    'R2',
#                                                    None,
#                                                    None)],
#                                           0)],
#                               'R1',
#                               None,
#                               None)],
#                      0),
#           1,
#           [Leaf(AndPredicate([gte(1), lte(31)]), Token('05', [0, 2), 'INT')),
#            Leaf(DictionaryPredicate({'август',
#                                      'августа',
#                                      'апрель',
#                                      'декабрь',
#                                      'июль',
#                                      'июнь',
#                                      'май',
#                                      'март',
#                                      'марта',
#                                      'мая',
#                                      'ноябрь',
#                                      'октябрь',
#                                      'сентябрь',
#                                      'февраль',
#                                      'январь'}),
#                 MorphToken('февраля',
#                            [3, 10),
#                            'RU',
#                            [Form('февраль',
#                                  Grams(NOUN,gent,inan,masc,sing))])),
#            Leaf(AndPredicate([gte(1), lte(2018)]),
#                 Token('2011', [11, 15), 'INT')),
#            Node(BNFRule([EmptyProduction([], 0),
#                          Production([BNFRule([Production([caseless('г'),
#                                                           eq('.')],
#                                                          0),
#                                               Production([DictionaryPredicate({'год'})],
#                                                          0)],
#                                              'R2',
#                                              None,
#                                              None)],
#                                     0)],
#                         'R1',
#                         None,
#                         None),
#                 Production([BNFRule([Production([caseless('г'), eq('.')], 0),
#                                      Production([DictionaryPredicate({'год'})],
#                                                 0)],
#                                     'R2',
#                                     None,
#                                     None)],
#                            0),
#                 1,
#                 [Node(BNFRule([Production([caseless('г'), eq('.')], 0),
#                                Production([DictionaryPredicate({'год'})], 0)],
#                               'R2',
#                               None,
#                               None),
#                       Production([DictionaryPredicate({'год'})], 0),
#                       1,
#                       [Leaf(DictionaryPredicate({'год'}),
#                             MorphToken('года',
#                                        [16, 20),
#                                        'RU',
#                                        [Form('год',
#                                              Grams(NOUN,gent,inan,masc,sing)),
#                                         Form('год',
#                                              Grams(Infr,NOUN,inan,masc,nomn,plur)),
#                                         Form('год',
#                                              Grams(Infr,NOUN,accs,inan,masc,plur))]))])])]),
#      (0, 4))

# %%
Date = fact(
    'Date',
    ['year', 'month', 'day']
)


DAY = and_(
    gte(1),
    lte(31)
).interpretation(
    Date.day
)
MONTH = and_(
    gte(1),
    lte(12)
).interpretation(
    Date.month
)
YEAR = and_(
    gte(1),
    lte(2018)
).interpretation(
    Date.year
)
MONTH_NAME = dictionary(
    MONTHS
).interpretation(
    Date.month
)
DATE = or_(
    rule(YEAR, '-', MONTH, '-', DAY),
    rule(
        DAY,
        MONTH_NAME,
        YEAR,
        YEAR_WORDS.optional()
    )
).interpretation(Date)

# match = parser.match('05 февраля 2011 года')
# match

parser = Parser(DATE)

text = '''8 января 2014 года, 2018-12-01, 1 февраля 2014 года'''

for match in parser.findall(text):
    print(match.fact)
# Out:
# Date(year='2014', month='января', day='8')
# Date(year='2018', month='12', day='01')
# Date(year='2014', month='февраля', day='1')

# %%
Date = fact(
    'Date',
    ['year', 'month', 'day']
)

class Date(Date):
    @property
    def as_datetime(self):
        return date(self.year, self.month, self.day)


MONTHS = {
    'январь': 1,
    'февраль': 2,
    'март': 3,
    'апрель': 4,
    'мая': 5,
    'июнь': 6,
    'июль': 7,
    'август': 8,
    'сентябрь': 9,
    'октябрь': 10,
    'ноябрь': 11,
    'декабрь': 12
}


DAY = and_(
    gte(1),
    lte(31)
).interpretation(
    Date.day.custom(int)
)
MONTH = and_(
    gte(1),
    lte(12)
).interpretation(
    Date.month.custom(int)
)
YEAR = and_(
    gte(1),
    lte(2018)
).interpretation(
    Date.year.custom(int)
)
MONTH_NAME = dictionary(
    MONTHS
).interpretation(
    Date.month.normalized().custom(MONTHS.__getitem__)
)
DATE = or_(
    rule(YEAR, '-', MONTH, '-', DAY),
    rule(
        DAY,
        MONTH_NAME,
        YEAR,
        YEAR_WORDS.optional()
    )
).interpretation(Date)

parser = Parser(DATE)
text = '''8 января 2014 года, 2018-12-01'''
for match in parser.findall(text):
    record = match.fact
    print(record, repr(record.as_datetime))
# Out:
# Date(year=2014, month=1, day=8) datetime.date(2014, 1, 8)
# Date(year=2018, month=12, day=1) datetime.date(2018, 12, 1)
